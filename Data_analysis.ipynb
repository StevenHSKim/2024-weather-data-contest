# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# 데이터 불러오기
data = pd.read_csv('Data//train_data.csv')

# 데이터 정보 출력
print("Dataset Information:")
data.info()

# 데이터 예시 출력 (처음 10개 행)
print("\nFirst 10 rows of the dataset:")
print(data.head(5))
# Out:
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3156459 entries, 0 to 3156458
# Data columns (total 16 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   Unnamed: 0          int64
#  1   fog_train.year      object
#  2   fog_train.month     int64
#  3   fog_train.day       int64
#  4   fog_train.time      int64
#  5   fog_train.minute    int64
#  6   fog_train.stn_id    object
#  7   fog_train.ws10_deg  float64
#  8   fog_train.ws10_ms   float64
#  9   fog_train.ta        float64
#  10  fog_train.re        float64
#  11  fog_train.hm        float64
#  12  fog_train.sun10     float64
#  13  fog_train.ts        float64
#  14  fog_train.vis1      int64
#  15  fog_train.class     int64
# dtypes: float64(7), int64(7), object(2)
# memory usage: 385.3+ MB
#
# First 10 rows of the dataset:
#    Unnamed: 0 fog_train.year  fog_train.month  fog_train.day  fog_train.time  \
# 0           1              I                1              1               0
# 1           2              I                1              1               0
# 2           3              I                1              1               0
# 3           4              I                1              1               0
# 4           5              I                1              1               0
#
#    fog_train.minute fog_train.stn_id  fog_train.ws10_deg  fog_train.ws10_ms  \
# 0                10               AA                 0.0                0.0
# 1                20               AA                 0.0                0.0
# 2                30               AA                 0.0                0.0
# 3                40               AA                27.8                0.4
# 4                50               AA                59.7                0.5
#
#    fog_train.ta  fog_train.re  fog_train.hm  fog_train.sun10  fog_train.ts  \
# 0          -6.4           0.0          38.9              0.0          -2.8
# 1          -6.3           0.0          37.9              0.0          -2.7
# 2          -6.3           0.0          40.0              0.0          -2.6
# 3          -6.2           0.0          39.5              0.0          -2.6
# 4          -6.1           0.0          39.8              0.0          -2.5
#
#    fog_train.vis1  fog_train.class
# 0           20000                4
# 1           20000                4
# 2           20000                4
# 3           20000                4
# 4           20000                4

# %%
# 결측치 확인
print(data.isnull().sum())
# Out:
# Unnamed: 0            0
# fog_train.year        0
# fog_train.month       0
# fog_train.day         0
# fog_train.time        0
# fog_train.minute      0
# fog_train.stn_id      0
# fog_train.ws10_deg    0
# fog_train.ws10_ms     0
# fog_train.ta          0
# fog_train.re          0
# fog_train.hm          0
# fog_train.sun10       0
# fog_train.ts          0
# fog_train.vis1        0
# fog_train.class       0
# dtype: int64

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# 숫자형 열과 범주형 열 추출
numerical_cols = data.select_dtypes(include=['int64', 'float64']).columns
categorical_cols = data.select_dtypes(include=['object', 'category']).columns

print("\nNumerical Columns:", numerical_cols)
print("Categorical Columns:", categorical_cols)

# 각 열의 분포 시각화
def plot_numerical(data, col):
    fig, axes = plt.subplots(1, 2, figsize=(12, 5))
    sns.histplot(data[col], ax=axes[0], kde=True)
    axes[0].set_title(f'Histogram of {col}')
    sns.boxplot(x=data[col], ax=axes[1])
    axes[1].set_title(f'Boxplot of {col}')
    plt.show()

def plot_categorical(data, col):
    plt.figure(figsize=(8, 4))
    sns.countplot(x=col, data=data)
    plt.title(f'Countplot of {col}')
    plt.show()

# 수치형 변수 시각화
for col in numerical_cols:
    plot_numerical(data, col)

# 범주형 변수 시각화
for col in categorical_cols:
    plot_categorical(data, col)
# Out:
# Numerical Columns: Index(['Unnamed: 0', 'fog_train.month', 'fog_train.day', 'fog_train.time',
#        'fog_train.minute', 'fog_train.ws10_deg', 'fog_train.ws10_ms',
#        'fog_train.ta', 'fog_train.re', 'fog_train.hm', 'fog_train.sun10',
#        'fog_train.ts', 'fog_train.vis1', 'fog_train.class'],
#       dtype='object')
# Categorical Columns: Index(['fog_train.year', 'fog_train.stn_id'], dtype='object')
